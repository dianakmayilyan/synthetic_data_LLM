# %%
import pandas as pd
import datasets
import transformers

# %%
file_path = '../../Data/data.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#   customer_age_class region  basket_package_price_disc  \
# 0            70 - 74    NRW                      64.95
# 1            35 - 39    HSN                      44.98
# 2            35 - 39    NRW                      54.98
# 3            35 - 39    HSN                     209.84
# 4            25 - 29    NRW                      63.98
#
#    internet_package_price_disc  basket_days_until_contract_end  \
# 0                        54.97                             366
# 1                        44.98                             100
# 2                        54.98                              30
# 3                       209.84                              30
# 4                        63.98                             123
#
#    count_previous_cancellations_0_18         internet_product_name  flag_churn
# 0                                  0             3PLAY PREMIUM HRZ           0
# 1                                  0  RED INTERNET & PHONE CABLE U           1
# ...

# %%
pip install wandb
# Out:
# Looking in indexes: https://europe-west1-python.pkg.dev/vf-grp-aib-prd-mirror/pypi-repository/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 55.4 MB/s eta 0:00:00ta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.4/311.4 kB 9.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wandb

# %%
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/jupyter/.netrc
# wandb: Network error (SSLError), entering retry loop.
# True

# %%
from be_great import GReaT

categorical_columns = ['customer_age_class', 'region', 'internet_product_name']

for col in categorical_columns:
    data[col] = data[col].astype('category')

# %%
model = GReaT(llm='distilgpt2', batch_size=32,  epochs=50, fp16=True)
model.fit(data)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/autograd/graph.py:769: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at ../aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass

# %%
synthetic_data = model.sample(n_samples=10000)

# %%
synthetic_data.to_csv('great_data.csv', index=False)
